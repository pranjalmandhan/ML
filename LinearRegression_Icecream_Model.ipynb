# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("/content/Ice Cream.csv")
df
# Out:
#      Temperature  Revenue
# 0           24.6      535
# 1           26.1      626
# 2           27.8      661
# 3           20.6      488
# 4           11.6      317
# ..           ...      ...
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656
#
# [500 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Revenue        0
# dtype: int64

# %%
df.shape
# Out:
# (500, 2)

# %%
X_train, X_test, Y_train, Y_test  = train_test_split(df["Temperature"],df["Revenue"],test_size=0.2, random_state=42)

# %%
print(X_train)

print(Y_train)
# Out:
# 249    18.2
# 433     8.8
# 19     21.8
# 322    18.5
# 332    15.9
#        ...
# 106    23.8
# 270    24.7
# 348    38.2
# 435    16.0
# 102    14.3
# Name: Temperature, Length: 400, dtype: float64
# 249    474
# 433    247
# 19     535
# 322    464
# 332    380
#       ...
# 106    554
# 270    604
# 348    857
# 435    382
# 102    323
# Name: Revenue, Length: 400, dtype: int64

# %%
print(X_train.shape)
print(Y_train.shape)

print(X_test.shape)
print(Y_test.shape)
# Out:
# (400,)
# (400,)
# (100,)
# (100,)

# %%
print("Values of X_train = ",X_train.values)
print("Values of Y_train = ",Y_train.values)

print("Values of X_test = ",X_test.values)
print("Values of X_test = ",Y_test.values)
# Out:
# Values of X_train =  [18.2  8.8 21.8 18.5 15.9 33.3 26.9  4.3 29.3 19.5 28.6 35.5 24.9 19.
#  17.5 23.5 24.8 30.  29.4 18.8 24.9 21.4 15.2 19.8 20.2 27.  27.6 10.5
#  16.  42.  15.3 31.7  9.4 28.5 36.8 36.6 21.  23.9 42.6  9.7 19.9 24.
#  18.6 12.4 31.5 18.6 16.3 25.9 23.6 26.2 14.4 26.  15.7 26.  12.2 20.3
#  20.6 18.   5.4 16.4 25.5 28.3 27.8 35.2 28.8 19.5 15.7 30.9 31.2 28.5
#  17.6 28.3 27.  11.1 17.7 20.6 20.2 26.9 19.8 21.7 27.  30.7 26.2 24.8
#  34.7 19.7 24.4 11.7 22.4 32.8 15.  29.3 24.3 25.  27.8 16.4  8.7 23.1
#  12.3 21.7 26.6 29.1 14.3 13.4 28.  25.3 38.2 24.2 25.4 20.3 18.6 25.5
#  19.   7.8 17.7 39.8 33.6 21.6 24.6 19.2 18.4 22.3 22.3  9.9 12.5 23.3
#   6.4  8.8 25.1 14.4 18.5 14.4 17.2 13.8 28.8 35.1 34.1 16.5 24.6 27.
#  17.6 29.2 19.3 11.5 20.5 17.7 14.8 31.8 25.8 32.9 22.4 24.6 21.8 25.5
#  38.  20.6 29.5 10.2 19.3 21.9 26.5 30.6 26.2 20.3 19.3 29.8 27.2 19.4
#  31.  28.3 22.1 24.  25.5 21.3 17.   7.3 37.  30.5 22.2 19.1 24.5 26.3
# ...

# %%
x_train = X_train.values.reshape(-1,1)
y_train = Y_train.values.reshape(-1,1)
x_test= X_test.values.reshape(-1,1)
y_test= Y_test.values.reshape(-1,1)

# %%
print(x_train.shape)
print(y_train.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (400, 1)
# (400, 1)
# (100, 1)
# (100, 1)

# %%
lr= LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
x_test
# Out:
# array([[29.8],
#        [27.4],
#        [24. ],
#        [21.2],
#        [26.6],
#        [12.1],
#        [11.2],
#        [12.6],
#        [21.5],
#        [29.9],
#        [31.7],
#        [16.6],
#        [18. ],
#        [29.3],
#        [ 0.3],
#        [ 7.2],
#        [22.3],
#        [24.2],
#        [25.2],
#        [29.8],
#        [23.9],
#        [34.5],
#        [28.5],
#        [24.5],
#        [40.5],
#        [29. ],
#        [12.6],
#        [27.4],
#        [32.1],
#        [30.5],
#        [18.2],
#        [19.9],
#        [31.1],
#        [35.3],
#        [27.8],
#        [20.9],
#        [32.7],
#        [12.7],
#        [10.1],
#        [ 4. ],
#        [25.1],
#        [ 8.6],
#        [23.5],
#        [16.2],
#        [18.3],
#        [25.6],
#        [24.6],
#        [ 3.7],
#        [20.1],
#        [22.7],
#        [27. ],
#        [21.4],
#        [20.5],
#        [21.2],
#        [23.6],
#        [27.4],
#        [24.7],
#        [29.6],
# ...

# %%
print("Prediction value: ",r2_score(y_test,y_pred))
# Out:
# Prediction value:  0.9771509516333023

# %%
m = lr.coef_
c= lr.intercept_

x=99
y = m*x+c
y
# Out:
# array([[2163.19441818]])

# %%
plt.scatter(df["Temperature"],df["Revenue"])
plt.show()

# %%
plt.plot(x_train, lr.predict(x_train))
plt.show()

# %%
plt.scatter(df["Temperature"], df["Revenue"], color='blue', label='Actual Data')  # Scatter plot in Blue
plt.plot(x_train, lr.predict(x_train), color='red', linewidth=2, label='Regression Line')  # Regression line in Red
plt.xlabel("Temperature")
plt.ylabel("Revenue")
plt.title("Temperature vs Revenue")
plt.legend()  # Show labels
plt.show()
